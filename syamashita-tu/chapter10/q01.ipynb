# %% [markdown]
# 以下のシステム $y = \mathcal{S}\{x\}$ の線形性と時不変性を確認し，線形時不変システムをすべて挙げなさい．
# \begin{align}
# y[n] &= x[n] + 1　\\
# y[n] &= 2 x[n] + x[n-1]\\
# y[n] &= x[-n]\\
# y[n] &= x[n]^2\\
# y[n] &= 0.9 y[n-1] + x[n]\\
# \end{align}

# %% [markdown]
# (1) $\mathcal{S}\{ax_1[n] + bx_2[n]\} = ax[n] + 1 + bx_2[n] + 1$ = ax_1[n] + bx_2[n] + 2 =

# %% [markdown]
# |番号|線形成|時不変性|線形時不変性|
# |---|---|---|---|
# |1|○|×|×|
# |2|○|○|○|
# |3|×|×|×|
# |4|×|○|○|
# |5|

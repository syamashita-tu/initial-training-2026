# %% [markdown]
# ファに対応する周波数を持つ正弦波を
# サンプリング周波数 $F_s = 16000$ Hz で 3 秒間サンプリングした信号を作り，
# 保存しなさい

# %%
pip install soundfile
# Out:
# Collecting soundfile
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: cffi>=1.0 in /home/syamashita/initial-training-2026/venv/lib/python3.12/site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in /home/syamashita/initial-training-2026/venv/lib/python3.12/site-packages (from soundfile) (2.4.4)
# Requirement already satisfied: pycparser in /home/syamashita/initial-training-2026/venv/lib/python3.12/site-packages (from cffi>=1.0->soundfile) (3.0)
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.6 MB/s  0:00:00
# Installing collected packages: soundfile
# Successfully installed soundfile-0.13.1
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import numpy as np
import soundfile as sf

output_dir = Path("outputs/audio/chapter09")
output_dir.mkdir(parents=True, exist_ok=True)

fs = 16000
duration = 3

t = np.linspace(0, duration, int(fs * duration), endpoint=False)
x = np.sin(2 * np.pi * 698.456462866008 * t)

sf.write(output_dir / "q02.wav", x, fs)

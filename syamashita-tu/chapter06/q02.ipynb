# %% [markdown]
# $x(t) = e^{j 4\pi t}$ をサンプリング周波数 $F_s = 100$ Hz で1秒間サンプリングした離散時間信号 $x[n]$ を
# 時間，実部，虚部の3次元でプロットしなさい．
# また， $y(t) = e^{-j 4\pi t}$ を同様にプロットし，周波数が正のときと負のときで時間波形がどのように変わるか考察しなさい．

# %%
import numpy as np
import matplotlib.pyplot as plt

Fs = 100
T = 1
n = np.arange(Fs * T)
t = n / Fs

x = np.exp(1j * 4 * np.pi * t)
y = np.exp(-1j * 4 * np.pi * t)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot(t, np.real(x), np.imag(x), label="x(t)=exp(j4πt)")
ax.plot(t, np.real(y), np.imag(y), label="y(t)=exp(-j4πt)")
ax.set_xlabel("time [s]")
ax.set_ylabel("real")
ax.set_zlabel("imag")
ax.legend()
plt.show()

# %% [markdown]
# - $e^{j4 \pi t}$ は複素平面上を正方向に回転
# - $e^{-j4 \pi t}$ は複素平面上を逆方向に回転
# - 実部だけを見るとどちらも $\cos {4 \pi t}$
# - 虚部は符号が反転
